# %% [markdown]
# # Pandas 1.x Cookbook - Chapter 1 - Pandas Foundations
#
# We are using pandas as an open source data analysis and manipulation tool, that is built on top of the Python programming language
#
# Our references:
# * [Pandas 1.x Cookbook, 2nd Edition, by M. Harrison and T. Petrou](https://www.packtpub.com/product/pandas-1x-cookbook-second-edition/9781839213106)
#
# * [Pandas-Cookbook-Second-Edition Github](https://github.com/PacktPublishing/Pandas-Cookbook-Second-Edition)
#
# * [Google Colab](https://colab.research.google.com/)
#
# * [Python](https://www.python.org/) Version 3.12.1
#
# * [Pandas](https://pandas.pydata.org) Version: 2.2.0
#
# * [Numpy](https://numpy.org/) Version: 1.26

# %% [markdown]
# In this notebook we will:
# * Load the [python libraries](https://docs.python.org/3/library/index.html): pandas and numpy
# * Upload a dataset from the desktop to google colab
# * Load the dataset into pandas and display portions of it (head, tail, sample)
# * Display the dataframe index (row) attribute
# * Display the dataframe columns atrribute
# * Display the dataframe data attribute
# * Look at NumPy ndarrays

# %% [markdown]
# This script loads the pandas and numpy libraries

# %%
# Load the pandas and numpy libraries
import pandas as pd
import numpy as np

# %% [markdown]
# We can drag and drop data files (csv files) that we want to work with from our local drive into the google colab file icon (left side of the colab screen)
# * Download the [movie.csv](https://github.com/PacktPublishing/Pandas-Cookbook-Second-Edition/tree/master/data) file to your desktop
# * Click on the folder on left side of the approximate middle of the Colab screen
# * Drag and drop the train.csv file into the folder to upload it to Google Colab from your desktop
# * You will need to do this operation everytime you use the notebook

# %% [markdown]
# This script will import the movie.csv file into pandas and display a portion of the dataset

# %%
# load and display a portion of the dataset
df = pd.read_csv('movie.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# This script will display a shorter portion of the dataset using the .head(n) method, with the default value for n = 5, where n = the number of the first rows that are visible

# %%
# Display a portion of the dataset (first five rows)
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# This script will display a shorter portion of the dataset using the .tail(n) method, with the default value for n = 5, where n = the number of the last rows that are visible

# %%
# Display a portion of the dataset (last five rows)
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %% [markdown]
# This script displays a portion of the dataset using the .sample method

# %%
# Display a portion of the dataset
df.sample()
# Out:
#       color director_name  num_critic_for_reviews  duration  \
# 2913  Color      Tim Hill                    37.0      91.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 2913                     25.0                   611.0  Amber Valletta
#
#       actor_1_facebook_likes       gross               genres  ...  \
# 2913                   833.0  17292381.0  Comedy|Crime|Family  ...
#
#      num_user_for_reviews language  country  content_rating      budget  \
# 2913                 69.0  English      USA              PG  12000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2913      2001.0                  626.0        5.3          1.85
#
#      movie_facebook_likes
# 2913                  371
#
# [1 rows x 28 columns]

# %% [markdown]
# There are three dataFrame components:  index, columns, and data. The labels in index and column names allow for pulling out data based on the index and column name.

# %% [markdown]
# This script will provide an example of how to access the dataframe's index (row) component.

# %%
index = df.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %% [markdown]
# This script will provide an example of how to access the dataframe's column component.

# %%
columns = df.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# This script will provide an example of how to access the dataframe's data component.

# %%
data = df.to_numpy()
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %% [markdown]
# Beneath the index, columns, and data components are NumPy ndarrays (n-dimensional array). Most of pandas relies heavily on the ndarray. [An array object represents a multidimensional, homogeneous array of fixed-size items. An associated data-type object describes the format of each element in the array (its byte-order, how many bytes it occupies in memory, whether it is an integer, a floating point number, or something else, etc.)](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html)

# %%
df.values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
type(data)
# Out:
# numpy.ndarray
