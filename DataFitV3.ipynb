# %% [markdown]
# # Fit Data to Probability Distributions (Scipy, Numpy, Matplotlib, and Seaborn)
#
# Ref:
#
#   * Fitting Data to a Distribution in Python in Just 60 Seconds! - RiskByNumbers
#   * Scipy https://scipy.org/
#   * Code With Me : Monte Carlo Method (My First Real-Time Coding Video!) - Ritvikmath
#   * Numpy https://numpy.org/
#   * Matplotlib https://matplotlib.org/
#   * Seaborn https://seaborn.pydata.org/

# %% [markdown]
# Import the following library tools

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss
import numpy as np

# %% [markdown]
# Grab some weather data from the National Weather Service
# * https://www.weather.gov/
# * Save the data as a csv file and save the file to the same google drive folder where this .pynb notebook is located
# * Drag the csv file from your desktop (google drive) and drop it into the folder icon on the left side of google colab (you will have to do this each time you want to run this notebook)

# %%
df = pd.read_csv('wx_data.csv')
data = df['Temp']

# %% [markdown]
# Plot the data

# %%
datasort = data.sort_values()
plt.figure(figsize = (2,1.25))
plt.hist(data,density = True)
plt.show()

# %% [markdown]
# Fit the data to the normal distribution using scipy
# * scipy.stats.norm
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
normfit = ss.norm.fit(data)
print("avg, ", "standard deviation")
print(normfit)
# Out:
# avg,  standard deviation
# (33.833333333333336, 1.8633899812498247)

# %% [markdown]
# Plot the data with the normal distribution using scipy

# %%
datasort = data.sort_values()
plt.figure(figsize = (2,1.25))
plt.hist(data,density = True)
plt.plot(datasort, ss.norm.pdf(datasort, *normfit))

# %% [markdown]
# Fit the data to the exponential distribution using scipy
# * scipy.stats.expon
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html

# %%
exponfit = ss.expon.fit(data)
print("avg,", "standard deviation")
print(exponfit)
# Out:
# avg, standard deviation
# (32.0, 1.8333333333333357)

# %% [markdown]
# Plot the data with the exponential distribution using scipy

# %%
datasort = data.sort_values()
plt.figure(figsize = (2,1.25))
plt.hist(data, density = True)
plt.plot(datasort, ss.expon.pdf(datasort, *exponfit))

# %% [markdown]
# Fit the data to the uniform distribution using scipy
# * scipy.stats.uniform
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html

# %%
unifit = ss.uniform.fit(data)
print("avg,", "standard deviation")
print(unifit)
# Out:
# avg, standard deviation
# (32.0, 5.0)

# %% [markdown]
# Plot the data with the uniform distribution using scipy

# %%
datasort = data.sort_values()
plt.figure(figsize = (2, 1.25))
plt.hist(data, density= True)
plt.plot(datasort, ss.uniform.pdf(datasort, *unifit))

# %% [markdown]
# Normal distribution examples with numpy, scipy, and seaborn
# * https://stackoverflow.com/questions/20011122/fitting-a-normal-distribution-to-1d-data
# * https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# * `distplot` is a deprecated function and will be removed in seaborn v0.14.0

# %%
import numpy as np
import seaborn as sns
from scipy.stats import norm

# Generate simulated data
n_samples = 100
rng = np.random.RandomState(0)
data = rng.standard_normal(n_samples)

# Fit Gaussian distribution and plot
sns.distplot(data, fit=norm, kde=False)
# Out:
# <ipython-input-1-462f2298b4ed>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, fit=norm, kde=False)
# <Axes: >

# %%
import seaborn as sns
sns.set_theme()
df = sns.load_dataset("penguins")

# %% [markdown]
# 'In its most basic invocation, distplot shows both a histogram (using density normalization) and a superimposed kernel density estimate:'

# %%
sns.distplot(df["flipper_length_mm"])
# Out:
# <ipython-input-3-ad61a6464634>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["flipper_length_mm"])
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# 'Replicating basic distplot output'

# %%
sns.histplot(df["flipper_length_mm"], kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>
